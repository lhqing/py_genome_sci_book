# %% [markdown]
# # FASTQ QC

# %% [markdown]
# ## Aims of this notebook
# - Trim the FASTQ by base quality, remove potential illumina adapter that may cause problem in mapping, and filter out short reads
# - Update the metadata table using new file names

# %% [markdown]
# ## Installation
#
# ### Install cutadapt, fastqc
# `conda install -n genome_book -c bioconda cutadapt fastqc`
#
# ### Install trim_galore
# see [trim galore github](https://github.com/FelixKrueger/TrimGalore) for instruction.
# ```{shell}
# curl -fsSL https://github.com/FelixKrueger/TrimGalore/archive/0.6.5.tar.gz -o trim_galore.tar.gz
# tar xvzf trim_galore.tar.gz
# # Run Trim Galore
# ./TrimGalore-0.6.5/trim_galore
# ```

# %%
import pandas as pd
import pathlib
import subprocess

# %%
fastq_meta = pd.read_csv('./data/fastq/fastq_metadata.csv', index_col=0)
fastq_meta
# Out:
#                count_type experiment_id   bio_sample_id     tissue  replicate  \
# File accession
# ENCFF329ACL         reads   ENCSR160IIN  UBERON:0001890  forebrain          1
# ENCFF251LNG         reads   ENCSR160IIN  UBERON:0001890  forebrain          2
# ENCFF896COV         reads   ENCSR160IIN  UBERON:0001890  forebrain          2
# ENCFF959PSX         reads   ENCSR970EWM  UBERON:0001890  forebrain          2
# ENCFF235DNM         reads   ENCSR970EWM  UBERON:0001890  forebrain          1
# ENCFF270GKY         reads   ENCSR185LWM  UBERON:0001890  forebrain          1
# ENCFF460TCF         reads   ENCSR185LWM  UBERON:0001890  forebrain          1
# ENCFF126IRS         reads   ENCSR185LWM  UBERON:0001890  forebrain          2
# ENCFF748SRJ         reads   ENCSR185LWM  UBERON:0001890  forebrain          2
# ENCFF447EXU         reads   ENCSR362AIZ  UBERON:0001890  forebrain          2
# ENCFF037JQC         reads   ENCSR362AIZ  UBERON:0001890  forebrain          1
# ENCFF458NWF         reads   ENCSR362AIZ  UBERON:0001890  forebrain          2
# ENCFF358MFI         reads   ENCSR362AIZ  UBERON:0001890  forebrain          1
# ENCFF891HIX         reads   ENCSR752RGN  UBERON:0001890  forebrain          2
# ENCFF179JEC         reads   ENCSR752RGN  UBERON:0001890  forebrain          1
# ENCFF203BWA         reads   ENCSR647QBV  UBERON:0001890  forebrain          2
# ENCFF920QAY         reads   ENCSR647QBV  UBERON:0001890  forebrain          1
# ENCFF294JRP         reads   ENCSR647QBV  UBERON:0001890  forebrain          1
# ENCFF700OLU         reads   ENCSR647QBV  UBERON:0001890  forebrain          2
# ENCFF920CNZ         reads   ENCSR304RDL  UBERON:0001890  forebrain          1
# ENCFF320FJX         reads   ENCSR304RDL  UBERON:0001890  forebrain          1
# ENCFF528EVC         reads   ENCSR304RDL  UBERON:0001890  forebrain          2
# ENCFF663SNC         reads   ENCSR304RDL  UBERON:0001890  forebrain          2
# ENCFF931IVO         reads   ENCSR080EVZ  UBERON:0001890  forebrain          1
# ENCFF114DRT         reads   ENCSR080EVZ  UBERON:0001890  forebrain          2
#
#                dev_time                               file_name
# File accession
# ENCFF329ACL       E11.5  forebrain_E11.5_1_ENCFF329ACL.fastq.gz
# ENCFF251LNG       E11.5  forebrain_E11.5_2_ENCFF251LNG.fastq.gz
# ENCFF896COV       E11.5  forebrain_E11.5_2_ENCFF896COV.fastq.gz
# ENCFF959PSX       E13.5  forebrain_E13.5_2_ENCFF959PSX.fastq.gz
# ENCFF235DNM       E13.5  forebrain_E13.5_1_ENCFF235DNM.fastq.gz
# ENCFF270GKY       E14.5  forebrain_E14.5_1_ENCFF270GKY.fastq.gz
# ENCFF460TCF       E14.5  forebrain_E14.5_1_ENCFF460TCF.fastq.gz
# ENCFF126IRS       E14.5  forebrain_E14.5_2_ENCFF126IRS.fastq.gz
# ENCFF748SRJ       E14.5  forebrain_E14.5_2_ENCFF748SRJ.fastq.gz
# ENCFF447EXU          P0     forebrain_P0_2_ENCFF447EXU.fastq.gz
# ENCFF037JQC          P0     forebrain_P0_1_ENCFF037JQC.fastq.gz
# ENCFF458NWF          P0     forebrain_P0_2_ENCFF458NWF.fastq.gz
# ENCFF358MFI          P0     forebrain_P0_1_ENCFF358MFI.fastq.gz
# ENCFF891HIX       E15.5  forebrain_E15.5_2_ENCFF891HIX.fastq.gz
# ENCFF179JEC       E15.5  forebrain_E15.5_1_ENCFF179JEC.fastq.gz
# ENCFF203BWA       E12.5  forebrain_E12.5_2_ENCFF203BWA.fastq.gz
# ENCFF920QAY       E12.5  forebrain_E12.5_1_ENCFF920QAY.fastq.gz
# ENCFF294JRP       E12.5  forebrain_E12.5_1_ENCFF294JRP.fastq.gz
# ENCFF700OLU       E12.5  forebrain_E12.5_2_ENCFF700OLU.fastq.gz
# ENCFF920CNZ       E10.5  forebrain_E10.5_1_ENCFF920CNZ.fastq.gz
# ENCFF320FJX       E10.5  forebrain_E10.5_1_ENCFF320FJX.fastq.gz
# ENCFF528EVC       E10.5  forebrain_E10.5_2_ENCFF528EVC.fastq.gz
# ENCFF663SNC       E10.5  forebrain_E10.5_2_ENCFF663SNC.fastq.gz
# ENCFF931IVO       E16.5  forebrain_E16.5_1_ENCFF931IVO.fastq.gz
# ENCFF114DRT       E16.5  forebrain_E16.5_2_ENCFF114DRT.fastq.gz

# %%
output_dir = pathlib.Path('./data/fastq/trimmed/').absolute()
# another way to make dir
output_dir.mkdir(exist_ok=True)

fastq_dir = pathlib.Path('./data/fastq/').absolute()

# %% [markdown]
# ## Run commands sequentially

# %%
# change this to your path to trim_galore installation
trim_galore_path = '/Users/hq/Documents/pkg/TrimGalore-0.6.5/trim_galore'

# iterate through each file in the fastq_meta
for file_name in fastq_meta['file_name']:
    file_path = fastq_dir / file_name
    # make the command using f-string
    command = f'{trim_galore_path} {file_path} --fastqc -o {output_dir}'
    # execute the command using subprocess
    subprocess.run(command, shell=True, check=True)
    
    print(command)
    print(file_name, 'trim finished.')
# Out:
# /Users/hq/Documents/pkg/TrimGalore-0.6.5/trim_galore /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/forebrain_E11.5_1_ENCFF329ACL.fastq.gz --fastqc -o /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed
# forebrain_E11.5_1_ENCFF329ACL.fastq.gz trim finished.
# /Users/hq/Documents/pkg/TrimGalore-0.6.5/trim_galore /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/forebrain_E11.5_2_ENCFF251LNG.fastq.gz --fastqc -o /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed
# forebrain_E11.5_2_ENCFF251LNG.fastq.gz trim finished.
# /Users/hq/Documents/pkg/TrimGalore-0.6.5/trim_galore /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/forebrain_E11.5_2_ENCFF896COV.fastq.gz --fastqc -o /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed
# forebrain_E11.5_2_ENCFF896COV.fastq.gz trim finished.
# /Users/hq/Documents/pkg/TrimGalore-0.6.5/trim_galore /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/forebrain_E13.5_2_ENCFF959PSX.fastq.gz --fastqc -o /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed
# forebrain_E13.5_2_ENCFF959PSX.fastq.gz trim finished.
# /Users/hq/Documents/pkg/TrimGalore-0.6.5/trim_galore /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/forebrain_E13.5_1_ENCFF235DNM.fastq.gz --fastqc -o /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed
# forebrain_E13.5_1_ENCFF235DNM.fastq.gz trim finished.
# /Users/hq/Documents/pkg/TrimGalore-0.6.5/trim_galore /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/forebrain_E14.5_1_ENCFF270GKY.fastq.gz --fastqc -o /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed
# forebrain_E14.5_1_ENCFF270GKY.fastq.gz trim finished.
# /Users/hq/Documents/pkg/TrimGalore-0.6.5/trim_galore /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/forebrain_E14.5_1_ENCFF460TCF.fastq.gz --fastqc -o /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed
# forebrain_E14.5_1_ENCFF460TCF.fastq.gz trim finished.
# /Users/hq/Documents/pkg/TrimGalore-0.6.5/trim_galore /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/forebrain_E14.5_2_ENCFF126IRS.fastq.gz --fastqc -o /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed
# forebrain_E14.5_2_ENCFF126IRS.fastq.gz trim finished.
# /Users/hq/Documents/pkg/TrimGalore-0.6.5/trim_galore /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/forebrain_E14.5_2_ENCFF748SRJ.fastq.gz --fastqc -o /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed
# forebrain_E14.5_2_ENCFF748SRJ.fastq.gz trim finished.
# /Users/hq/Documents/pkg/TrimGalore-0.6.5/trim_galore /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/forebrain_P0_2_ENCFF447EXU.fastq.gz --fastqc -o /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed
# forebrain_P0_2_ENCFF447EXU.fastq.gz trim finished.
# /Users/hq/Documents/pkg/TrimGalore-0.6.5/trim_galore /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/forebrain_P0_1_ENCFF037JQC.fastq.gz --fastqc -o /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed
# forebrain_P0_1_ENCFF037JQC.fastq.gz trim finished.
# /Users/hq/Documents/pkg/TrimGalore-0.6.5/trim_galore /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/forebrain_P0_2_ENCFF458NWF.fastq.gz --fastqc -o /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed
# forebrain_P0_2_ENCFF458NWF.fastq.gz trim finished.
# /Users/hq/Documents/pkg/TrimGalore-0.6.5/trim_galore /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/forebrain_P0_1_ENCFF358MFI.fastq.gz --fastqc -o /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed
# forebrain_P0_1_ENCFF358MFI.fastq.gz trim finished.
# /Users/hq/Documents/pkg/TrimGalore-0.6.5/trim_galore /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/forebrain_E15.5_2_ENCFF891HIX.fastq.gz --fastqc -o /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed
# forebrain_E15.5_2_ENCFF891HIX.fastq.gz trim finished.
# /Users/hq/Documents/pkg/TrimGalore-0.6.5/trim_galore /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/forebrain_E15.5_1_ENCFF179JEC.fastq.gz --fastqc -o /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed
# forebrain_E15.5_1_ENCFF179JEC.fastq.gz trim finished.
# /Users/hq/Documents/pkg/TrimGalore-0.6.5/trim_galore /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/forebrain_E12.5_2_ENCFF203BWA.fastq.gz --fastqc -o /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed
# forebrain_E12.5_2_ENCFF203BWA.fastq.gz trim finished.
# /Users/hq/Documents/pkg/TrimGalore-0.6.5/trim_galore /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/forebrain_E12.5_1_ENCFF920QAY.fastq.gz --fastqc -o /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed
# forebrain_E12.5_1_ENCFF920QAY.fastq.gz trim finished.
# /Users/hq/Documents/pkg/TrimGalore-0.6.5/trim_galore /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/forebrain_E12.5_1_ENCFF294JRP.fastq.gz --fastqc -o /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed
# forebrain_E12.5_1_ENCFF294JRP.fastq.gz trim finished.
# /Users/hq/Documents/pkg/TrimGalore-0.6.5/trim_galore /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/forebrain_E12.5_2_ENCFF700OLU.fastq.gz --fastqc -o /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed
# forebrain_E12.5_2_ENCFF700OLU.fastq.gz trim finished.
# /Users/hq/Documents/pkg/TrimGalore-0.6.5/trim_galore /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/forebrain_E10.5_1_ENCFF920CNZ.fastq.gz --fastqc -o /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed
# forebrain_E10.5_1_ENCFF920CNZ.fastq.gz trim finished.
# /Users/hq/Documents/pkg/TrimGalore-0.6.5/trim_galore /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/forebrain_E10.5_1_ENCFF320FJX.fastq.gz --fastqc -o /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed
# forebrain_E10.5_1_ENCFF320FJX.fastq.gz trim finished.
# /Users/hq/Documents/pkg/TrimGalore-0.6.5/trim_galore /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/forebrain_E10.5_2_ENCFF528EVC.fastq.gz --fastqc -o /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed
# forebrain_E10.5_2_ENCFF528EVC.fastq.gz trim finished.
# /Users/hq/Documents/pkg/TrimGalore-0.6.5/trim_galore /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/forebrain_E10.5_2_ENCFF663SNC.fastq.gz --fastqc -o /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed
# forebrain_E10.5_2_ENCFF663SNC.fastq.gz trim finished.
# /Users/hq/Documents/pkg/TrimGalore-0.6.5/trim_galore /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/forebrain_E16.5_1_ENCFF931IVO.fastq.gz --fastqc -o /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed
# forebrain_E16.5_1_ENCFF931IVO.fastq.gz trim finished.
# /Users/hq/Documents/pkg/TrimGalore-0.6.5/trim_galore /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/forebrain_E16.5_2_ENCFF114DRT.fastq.gz --fastqc -o /Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed
# forebrain_E16.5_2_ENCFF114DRT.fastq.gz trim finished.

# %% [markdown]
# ## [OPTIONAL] Run commands in parallel
# - When you have multiple samples, it is important to learn how to execute commands in parallel, so you can utilize power of your multi-core laptop or server.

# %%
# Based on the number of cores your computer has
process = 4

# this is one way to run things in parallel in python
from concurrent.futures import ProcessPoolExecutor, as_completed
import subprocess

# %%
trim_galore_path = '/Users/hq/Documents/pkg/TrimGalore-0.6.5/trim_galore'
with ProcessPoolExecutor(process) as executor:
    #executor is a process pool, it will control the number of processes run in parallel
    
    futures = {}
    for file_name in fastq_meta['file_name']:
        file_path = fastq_dir / file_name
        command = f'{trim_galore_path} {file_path} --fastqc -o {output_dir}'
        
        # executor.submit a job (run a function with certain parameter, here the function is subprocess.run) 
        # and return a future obj. The future obj refer to this job, save it into futures first
        future = executor.submit(subprocess.run, command, shell=True, check=True)
        futures[future] = file_name
    
    # as_complete determine which future is finished
    for future in as_completed(futures):
        # get back the file name associated to this future
        file_name = futures[future]
        
        # this line is important, it check wheter the job finished without error
        # it will also got the job (subprocess.run) return, here that's not important
        _ = future.result()
        
        print(file_name, 'trim finished.')
# Out:
# forebrain_E13.5_2_ENCFF959PSX.fastq.gz trim finished.
# forebrain_E11.5_1_ENCFF329ACL.fastq.gz trim finished.
# forebrain_E11.5_2_ENCFF251LNG.fastq.gz trim finished.
# forebrain_E11.5_2_ENCFF896COV.fastq.gz trim finished.
# forebrain_E13.5_1_ENCFF235DNM.fastq.gz trim finished.
# forebrain_E14.5_1_ENCFF460TCF.fastq.gz trim finished.
# forebrain_E14.5_1_ENCFF270GKY.fastq.gz trim finished.
# forebrain_E14.5_2_ENCFF126IRS.fastq.gz trim finished.
# forebrain_E14.5_2_ENCFF748SRJ.fastq.gz trim finished.
# forebrain_P0_1_ENCFF037JQC.fastq.gz trim finished.
# forebrain_P0_2_ENCFF447EXU.fastq.gz trim finished.
# forebrain_P0_2_ENCFF458NWF.fastq.gz trim finished.
# forebrain_E15.5_2_ENCFF891HIX.fastq.gz trim finished.
# forebrain_E12.5_2_ENCFF203BWA.fastq.gz trim finished.
# forebrain_P0_1_ENCFF358MFI.fastq.gz trim finished.
# forebrain_E15.5_1_ENCFF179JEC.fastq.gz trim finished.
# forebrain_E10.5_1_ENCFF920CNZ.fastq.gz trim finished.
# forebrain_E12.5_1_ENCFF294JRP.fastq.gz trim finished.
# forebrain_E12.5_1_ENCFF920QAY.fastq.gz trim finished.
# forebrain_E12.5_2_ENCFF700OLU.fastq.gz trim finished.
# forebrain_E10.5_1_ENCFF320FJX.fastq.gz trim finished.
# forebrain_E10.5_2_ENCFF663SNC.fastq.gz trim finished.
# forebrain_E16.5_1_ENCFF931IVO.fastq.gz trim finished.
# forebrain_E10.5_2_ENCFF528EVC.fastq.gz trim finished.
# forebrain_E16.5_2_ENCFF114DRT.fastq.gz trim finished.

# %% [markdown]
# ## Make metadata for trimmed fastq

# %%
# find out all the trimmed fastq, make a dict
fastq_list = list(output_dir.glob('*trimmed.fq.gz'))
fastq_list[:5]
# Out:
# [PosixPath('/Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed/forebrain_E12.5_1_ENCFF920QAY_trimmed.fq.gz'),
#  PosixPath('/Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed/forebrain_E12.5_1_ENCFF294JRP_trimmed.fq.gz'),
#  PosixPath('/Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed/forebrain_P0_2_ENCFF447EXU_trimmed.fq.gz'),
#  PosixPath('/Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed/forebrain_E11.5_2_ENCFF896COV_trimmed.fq.gz'),
#  PosixPath('/Users/hq/Documents/pkg/py_genome_sci_book/analysis/salmon_demo/data/fastq/trimmed/forebrain_E15.5_1_ENCFF179JEC_trimmed.fq.gz')]

# %%
# replace the fastq path with trimmed ones
fastq_series = pd.Series({i.name.split('_')[3]: str(i) for i in fastq_list})
fastq_meta['file_name'] = fastq_series

# %%
fastq_meta
# Out:
#                count_type experiment_id   bio_sample_id     tissue  replicate  \
# File accession
# ENCFF329ACL         reads   ENCSR160IIN  UBERON:0001890  forebrain          1
# ENCFF251LNG         reads   ENCSR160IIN  UBERON:0001890  forebrain          2
# ENCFF896COV         reads   ENCSR160IIN  UBERON:0001890  forebrain          2
# ENCFF959PSX         reads   ENCSR970EWM  UBERON:0001890  forebrain          2
# ENCFF235DNM         reads   ENCSR970EWM  UBERON:0001890  forebrain          1
# ENCFF270GKY         reads   ENCSR185LWM  UBERON:0001890  forebrain          1
# ENCFF460TCF         reads   ENCSR185LWM  UBERON:0001890  forebrain          1
# ENCFF126IRS         reads   ENCSR185LWM  UBERON:0001890  forebrain          2
# ENCFF748SRJ         reads   ENCSR185LWM  UBERON:0001890  forebrain          2
# ENCFF447EXU         reads   ENCSR362AIZ  UBERON:0001890  forebrain          2
# ENCFF037JQC         reads   ENCSR362AIZ  UBERON:0001890  forebrain          1
